# %%
higher_order_lambda = lambda f: lambda x: f(x)
g = lambda x: x * x
# higher_order_lambda(2)
# higher_order_lambda(2)(g) # TypeError: 'int' object is not callable

# %%
def hop():
    """
    Calling hop returns a curried version of the function f(x, y) = y.
    >>> hop()(3)(2) # .Case 1
    2
    >>> hop()(3)(7) # .Case 2
    7
    >>> hop()(4)(7) # .Case 3
    7
    """
    "*** YOUR CODE HERE ***"
    return lambda x : lambda y : y
        

from doctest import run_docstring_examples
run_docstring_examples(hop, globals(), True)
# Out:
# Finding tests in NoName
# Trying:
#     hop()(3)(2) # .Case 1
# Expecting:
#     2
# ok
# Trying:
#     hop()(3)(7) # .Case 2
# Expecting:
#     7
# ok
# Trying:
#     hop()(4)(7) # .Case 3
# Expecting:
#     7
# ok

# %%
def digit_index_factory(num, k):
    """
    Returns a function that takes no arguments, and outputs the offset
    between k and the rightmost digit of num. If k is not in num, then
    the returned function returns -1. Note that 0 is considered to
    contain no digits (not even 0).
    >>> digit_index_factory(34567, 4)() # .Case 1
    3
    >>> digit_index_factory(30001, 0)() # .Case 2
    1
    >>> digit_index_factory(999, 1)() # .Case 3
    -1
    >>> digit_index_factory(1234, 0)() # .Case 4
    -1
    """
    "*** YOUR CODE HERE ***"
    def function_digit():
        return re
    
    if num == 0:
        re = -1
    else:
        digits_reverse = [str(d) for d in str(num)[::-1]] # string array containing each digit from rightmost
        try:
            re = digits_reverse.index(str(k))
        except ValueError: # k not in the digits of num
            re = -1
    return function_digit

run_docstring_examples(digit_index_factory, globals(), True)
# Out:
# Finding tests in NoName
# Trying:
#     digit_index_factory(34567, 4)() # .Case 1
# Expecting:
#     3
# ok
# Trying:
#     digit_index_factory(30001, 0)() # .Case 2
# Expecting:
#     1
# ok
# Trying:
#     digit_index_factory(999, 1)() # .Case 3
# Expecting:
#     -1
# ok
# Trying:
#     digit_index_factory(1234, 0)() # .Case 4
# Expecting:
#     -1
# ok

# %%
def lambda_curry2(func):
    """
    Returns a Curried version of a two-argument function FUNC.
    >>> from operator import add, mul, mod
    >>> curried_add = lambda_curry2(add)
    >>> add_three = curried_add(3)
    >>> add_three(5)
    8
    >>> curried_mul = lambda_curry2(mul)
    >>> mul_5 = curried_mul(5)
    >>> mul_5(42)
    210
    >>> lambda_curry2(mod)(123)(10)
    3
    """
    "*** YOUR CODE HERE ***"
    return lambda x: lambda y: func(x,y)
    
from operator import add, mul, mod
run_docstring_examples(lambda_curry2, globals(), True)
# Out:
# Finding tests in NoName
# Trying:
#     from operator import add, mul, mod
# Expecting nothing
# ok
# Trying:
#     curried_add = lambda_curry2(add)
# Expecting nothing
# ok
# Trying:
#     add_three = curried_add(3)
# Expecting nothing
# ok
# Trying:
#     add_three(5)
# Expecting:
#     8
# ok
# Trying:
#     curried_mul = lambda_curry2(mul)
# Expecting nothing
# ok
# Trying:
#     mul_5 = curried_mul(5)
# Expecting nothing
# ok
# Trying:
#     mul_5(42)
# Expecting:
#     210
# ok
# Trying:
#     lambda_curry2(mod)(123)(10)
# Expecting:
#     3
# ok

# %%
def count_factors(n):
    """Return the number of positive factors that n has.
    >>> count_factors(6)
    4   # 1, 2, 3, 6
    >>> count_factors(4)
    3   # 1, 2, 4
    """
    i = 1
    count = 0
    while i <= n:
        if n % i == 0:
            count += 1
        i += 1
    return count

def count_primes(n):
    """Return the number of prime numbers up to and including n.
    >>> count_primes(6)
    3   # 2, 3, 5
    >>> count_primes(13)
    6   # 2, 3, 5, 7, 11, 13
    """
    i = 1
    count = 0
    while i <= n:
        if is_prime(i):
            count += 1
        i += 1
    return count

def is_prime(n):
    return count_factors(n) == 2 # only factors are 1 and n

# %%
count_cond(lambda n, i: n % i == 0)(2)
# Out:
# <function __main__.count_cond.<locals>.re_function(condition)>

# %%
def count_cond(condition):
    """Returns a function with one parameter N that counts all the numbers from
    1 to N that satisfy the two-argument predicate function Condition, where
    the first argument for Condition is N and the second argument is the
    number from 1 to N.

    >>> count_factors = count_cond(lambda n, i: n % i == 0) # arg is lambda func, output=bool
    >>> count_factors(2)   # 1, 2
    2
    >>> count_factors(4)   # 1, 2, 4
    3
    >>> count_factors(12)  # 1, 2, 3, 4, 6, 12
    6

    >>> is_prime = lambda n, i: count_factors(i) == 2
    >>> count_primes = count_cond(is_prime)
    >>> count_primes(2)    # 2
    1
    >>> count_primes(3)    # 2, 3
    2
    >>> count_primes(4)    # 2, 3
    2
    >>> count_primes(5)    # 2, 3, 5
    3
    >>> count_primes(20)   # 2, 3, 5, 7, 11, 13, 17, 19
    8
    """
    "*** YOUR CODE HERE ***"
    def re_function(n):
        i = 1
        count = 0
        while i <= n:
            if condition(n, i):
                count += 1
            i += 1
        return count
    return re_function

run_docstring_examples(count_cond, globals(), True)
# Out:
# Finding tests in NoName
# Trying:
#     count_factors = count_cond(lambda n, i: n % i == 0) # arg is lambda func, output=bool
# Expecting nothing
# ok
# Trying:
#     count_factors(2)   # 1, 2
# Expecting:
#     2
# ok
# Trying:
#     count_factors(4)   # 1, 2, 4
# Expecting:
#     3
# ok
# Trying:
#     count_factors(12)  # 1, 2, 3, 4, 6, 12
# Expecting:
#     6
# ok
# Trying:
#     is_prime = lambda n, i: count_factors(i) == 2
# Expecting nothing
# ok
# Trying:
#     count_primes = count_cond(is_prime)
# Expecting nothing
# ok
# Trying:
#     count_primes(2)    # 2
# Expecting:
#     1
# ok
# Trying:
#     count_primes(3)    # 2, 3
# Expecting:
#     2
# ok
# Trying:
#     count_primes(4)    # 2, 3
# Expecting:
#     2
# ok
# Trying:
#     count_primes(5)    # 2, 3, 5
# Expecting:
#     3
# ok
# Trying:
#     count_primes(20)   # 2, 3, 5, 7, 11, 13, 17, 19
# Expecting:
#     8
# ok

# %%
def composer(f, g):
    """Return the composition function which given x, computes f(g(x)).

    >>> add_one = lambda x: x + 1        # adds one to x
    >>> square = lambda x: x**2
    >>> a1 = composer(square, add_one)   # (x + 1)^2
    >>> a1(4)
    25
    >>> mul_three = lambda x: x * 3      # multiplies 3 to x
    >>> a2 = composer(mul_three, a1)    # ((x + 1)^2) * 3
    >>> a2(4)
    75
    >>> a2(5)
    108
    """
    return lambda x: f(g(x))


def composite_identity(f, g):
    """
    Return a function with one parameter x that returns True if f(g(x)) is
    equal to g(f(x)). You can assume the result of g(x) is a valid input for f
    and vice versa.

    >>> add_one = lambda x: x + 1        # adds one to x
    >>> square = lambda x: x**2
    >>> b1 = composite_identity(square, add_one)
    >>> b1(0)                            # (0 + 1)^2 == 0^2 + 1
    True
    >>> b1(4)                            # (4 + 1)^2 != 4^2 + 1
    False
    """
    "*** YOUR CODE HERE ***"
    # def fun1(x):
    #     return composer(f, g)(x)
    # def fun2(x):
    #     return composer(g, f)(x)
    return lambda x : composer(f, g)(x) == composer(g, f)(x)
    
run_docstring_examples(composite_identity, globals(), True)
# Out:
# Finding tests in NoName
# Trying:
#     add_one = lambda x: x + 1        # adds one to x
# Expecting nothing
# ok
# Trying:
#     square = lambda x: x**2
# Expecting nothing
# ok
# Trying:
#     b1 = composite_identity(square, add_one)
# Expecting nothing
# ok
# Trying:
#     b1(0)                            # (0 + 1)^2 == 0^2 + 1
# Expecting:
#     True
# ok
# Trying:
#     b1(4)                            # (4 + 1)^2 != 4^2 + 1
# Expecting:
#     False
# ok

# %%
def cycle(f1, f2, f3):
    """Returns a function that is itself a higher-order function.
    n = 4 -> f1(f3(f2(f1(x))))

    >>> def add1(x):
    ...     return x + 1
    >>> def times2(x):
    ...     return x * 2
    >>> def add3(x):
    ...     return x + 3
    >>> my_cycle = cycle(add1, times2, add3)
    >>> identity = my_cycle(0)
    >>> identity(5)
    5
    >>> add_one_then_double = my_cycle(2)
    >>> add_one_then_double(1)
    4
    >>> do_all_functions = my_cycle(3)
    >>> do_all_functions(2)
    9
    >>> do_more_than_a_cycle = my_cycle(4)
    >>> do_more_than_a_cycle(2)
    10
    >>> do_two_cycles = my_cycle(6)
    >>> do_two_cycles(1)
    19
    """
    "*** YOUR CODE HERE ***"
    def do_cycle(n, x):
        func_list = []
        func_cycle = [f1, f2, f3] # outer functions come last

        ncycle = n // 3
        func_list = func_list + func_cycle * ncycle
        nremain = n % 3
        func_list = func_list + func_cycle[:nremain] # n%3 remnant are outer functions, comes last
        
        if n == 0:
            return x
        re = x
        for func in func_list:
            re = func(re)
        return re
    return lambda n: lambda x: do_cycle(n, x) # first get input n, then x!

run_docstring_examples(cycle, globals(), True)
# Out:
# Finding tests in NoName
# Trying:
#     def add1(x):
#         return x + 1
# Expecting nothing
# ok
# Trying:
#     def times2(x):
#         return x * 2
# Expecting nothing
# ok
# Trying:
#     def add3(x):
#         return x + 3
# Expecting nothing
# ok
# Trying:
#     my_cycle = cycle(add1, times2, add3)
# Expecting nothing
# ok
# Trying:
#     identity = my_cycle(0)
# Expecting nothing
# ok
# Trying:
#     identity(5)
# Expecting:
#     5
# ok
# Trying:
#     add_one_then_double = my_cycle(2)
# Expecting nothing
# ok
# Trying:
#     add_one_then_double(1)
# Expecting:
#     4
# ok
# Trying:
#     do_all_functions = my_cycle(3)
# Expecting nothing
# ok
# Trying:
#     do_all_functions(2)
# Expecting:
#     9
# ok
# Trying:
#     do_more_than_a_cycle = my_cycle(4)
# Expecting nothing
# ok
# Trying:
#     do_more_than_a_cycle(2)
# Expecting:
#     10
# ok
# Trying:
#     do_two_cycles = my_cycle(6)
# Expecting nothing
# ok
# Trying:
#     do_two_cycles(1)
# Expecting:
#     19
# ...
